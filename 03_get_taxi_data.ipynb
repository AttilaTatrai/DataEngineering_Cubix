# %%
import json
import os
import pandas as pd
import requests
from datetime import datetime
from dateutil.relativedelta import relativedelta

# %%
url = "https://data.cityofchicago.org/resource/ajtu-isnz.json?trip_id=00000a980db3a3a9295d53b26bbd72200a9ce92b"
headers = {"X-App-Token":os.environ.get("CHICHAGO_API_TOKEN")}
response = requests.get(url,headers)

data = response.json()

# %%
data
# Out:
# [{'trip_id': '00000a980db3a3a9295d53b26bbd72200a9ce92b',
#   'taxi_id': '6daab772b2fe0e6dcb68884525d6ad9d44ce74ecaeb417a02e6e2df1d21728cc81ce526da7de1a7ebdc27be9a4503e5c5860326d92438788459012201372bfad',
#   'trip_start_timestamp': '2024-03-23T08:45:00.000',
#   'trip_end_timestamp': '2024-03-23T08:45:00.000',
#   'trip_seconds': '319',
#   'trip_miles': '0.88',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '8',
#   'fare': '9',
#   'tips': '2.22',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '11.22',
#   'payment_type': 'Mobile',
#   'company': 'Sun Taxi',
#   'pickup_centroid_latitude': '41.899602111',
#   'pickup_centroid_longitude': '-87.633308037',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}}]

# %%
url = "https://data.cityofchicago.org/resource/6zsd-86xi.json?$where=date between '2024-04-12T00:00:00' and '2024-04-12T23:59:59'"
headers = {"X-App-Token":os.environ.get("CHICHAGO_API_TOKEN")}
response = requests.get(url,headers)

data = response.json()

# %%
len(data)
#data
# Out:
# 698

# %%
current_datetime = datetime.now() - relativedelta(months=2)
formatted_datetime = current_datetime.strftime("%Y-%m-%d") 

url = f"https://data.cityofchicago.org/resource/6zsd-86xi.json?$where=date between '{formatted_datetime}T00:00:00' and '{formatted_datetime}T23:59:59'"
headers = {"X-App-Token":os.environ.get("CHICHAGO_API_TOKEN")}
response = requests.get(url,headers)

data = response.json()
data
# Out:
# [{'id': '13383212',
#   'case_number': 'JH169537',
#   'date': '2024-02-28T00:00:00.000',
#   'block': '059XX S MAPLEWOOD AVE',
#   'iucr': '0584',
#   'primary_type': 'STALKING',
#   'description': 'VIOLATION OF STALKING NO CONTACT ORDER',
#   'location_description': 'RESIDENCE',
#   'arrest': False,
#   'domestic': False,
#   'beat': '0824',
#   'district': '008',
#   'ward': '16',
#   'community_area': '66',
#   'fbi_code': '26',
#   'x_coordinate': '1160390',
#   'y_coordinate': '1865166',
#   'year': '2024',
#   'updated_on': '2024-03-06T15:41:57.000',
#   'latitude': '41.785713083',
#   'longitude': '-87.68747757',
#   'location': {'type': 'Point', 'coordinates': [-87.68747757, 41.785713083]},
#   'location_address': '',
#   'location_city': '',
#   'location_state': '',
#   'location_zip': ''},
#  {'id': '13382636',
#   'case_number': 'JH168829',
#   'date': '2024-02-28T00:00:00.000',
#   'block': '060XX S COTTAGE GROVE AVE',
#   'iucr': '0860',
#   'primary_type': 'THEFT',
# ...
